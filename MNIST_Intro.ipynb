# %% [markdown]
# <a href="https://colab.research.google.com/github/bharaniakella/Akellian_DL/blob/main/MNIST_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
# import dataset (comes with colab!)
data = np.loadtxt(open('sample_data/mnist_train_small.csv','rb'),delimiter=',')

# %%
data.shape
# Out:
# (20000, 785)

# %%
labels=data[:,0]
num_data=data[:,1:]
# Out:
# ((20000,), (20000, 784))

# %%
np.random.randint(0,num_data.shape[0])
# Out:
# 14204

# %%
randimg2show = np.random.randint(0,high=data.shape[0])
img = np.reshape(num_data[randimg2show,:],(28,28))
plt.imshow(img)
plt.title(labels[randimg2show])
plt.show()

# %%
randimg2show = np.random.randint(0,high=data.shape[0])
img = np.reshape(num_data[randimg2show,:],(28,28))
plt.imshow(img,cmap='gray')
plt.title(labels[randimg2show])
plt.show()

# %%
# show a few random digits
fig,axs = plt.subplots(3,4,figsize=(10,6))

for ax in axs.flatten():
  # pick a random image
  randimg2show = np.random.randint(0,high=data.shape[0])

  # create the image (must be reshaped!)
  img = np.reshape(num_data[randimg2show,:],(28,28))
  ax.imshow(img,cmap='gray')

  # title
  ax.set_title('The number %i'%labels[randimg2show])

plt.suptitle('How humans see the data',fontsize=20)
plt.tight_layout(rect=[0,0,1,.95])
plt.show()

# %%
# show a few random digits
fig,axs = plt.subplots(3,4,figsize=(10,6))

for ax in axs.flatten():
  # pick a random image
  randimg2show = np.random.randint(0,high=data.shape[0])

  # create the image
  ax.plot(num_data[randimg2show,:],'ko')

  # title
  ax.set_title('The number %i'%labels[randimg2show])

plt.suptitle('How the FFN model sees the data',fontsize=20)
plt.tight_layout(rect=[0,0,1,.95])
plt.show()

# %%
np.where(labels==7)[0]
# Out:
# array([    2,    11,    12, ..., 19937, 19948, 19969])

# %%
# let's see some example 7s

# find indices of all the 7's in the dataset
the7s = np.where(labels==7)[0]

# draw the first 12
fig,axs = plt.subplots(2,6,figsize=(15,6))

for i,ax in enumerate(axs.flatten()):
  img = np.reshape(num_data[the7s[i],:],(28,28))
  ax.imshow(img,cmap='gray')
  ax.axis('off')

plt.suptitle("Example 7's",fontsize=20)
plt.tight_layout(rect=[0,0,1,.95])
plt.show()
